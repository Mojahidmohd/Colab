# %% [markdown]
# <a href="https://colab.research.google.com/github/Mojahidmohd/Colab/blob/main/CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from torchvision.utils import make_grid

import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
#make the plot appear in the same notebook after CMD
# %matplotlib inline

# %%
#convert MNIST Image File into tensor of 4-Dimension (# of images , Heights, Width, Color channels)
transform = transforms.ToTensor()

# %%
#Training data downloaded from library to /cnn_data in notbook
train_data = datasets.MNIST(root='/cnn_data', train=True, download=True, transform=transform)
# Out:
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 39.3MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 1.07MB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 9.90MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 6.83MB/s]

# %%
#Test Data
test_data = datasets.MNIST(root='/cnn_data', train=False, download=True, transform=transform)

# %%
train_data
# Out:
# Dataset MNIST
#     Number of datapoints: 60000
#     Root location: /cnn_data
#     Split: Train
#     StandardTransform
# Transform: ToTensor()

# %%
test_data
# Out:
# Dataset MNIST
#     Number of datapoints: 10000
#     Root location: /cnn_data
#     Split: Test
#     StandardTransform
# Transform: ToTensor()

# %%
#create a small batch size of images ...10
train_loader = DataLoader(train_data, batch_size=10, shuffle=True)
test_loader = DataLoader(test_data, batch_size=10, shuffle=False)

# %%
conv1 = nn.Conv2d(1, 6, 3, 1)
conv2 = nn.Conv2d(6, 16, 3, 1)

# %%
#Grab 1 MNIST Record/Image
for i, (X_train, y_train) in enumerate(train_data):
  break

# %%
X_train.shape
# Out:
# torch.Size([1, 28, 28])
